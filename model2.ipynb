# %%
# !python -m pip install pywin32 -U --force-reinstall
# Out:
# Collecting pywin32
#   Downloading pywin32-311-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Downloading pywin32-311-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB 330.3 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/9.5 MB 544.7 kB/s eta 0:00:18
#     --------------------------------------- 0.1/9.5 MB 853.3 kB/s eta 0:00:11
#     --------------------------------------- 0.2/9.5 MB 1.0 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/9.5 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.7/9.5 MB 2.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/9.5 MB 2.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/9.5 MB 2.5 MB/s eta 0:00:04
#    ------ --------------------------------- 1.5/9.5 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.5 MB 3.2 MB/s eta 0:00:03
#    -------- ------------------------------- 1.9/9.5 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.5 MB 3.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/9.5 MB 3.8 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.5 MB 4.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.5 MB 4.1 MB/s eta 0:00:02
#    -------------- ------------------------- 3.5/9.5 MB 4.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.8/9.5 MB 4.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.5 MB 4.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.6/9.5 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.5 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.3/9.5 MB 4.8 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.5 MB 4.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.5/9.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.5/9.5 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 7.8/9.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.3/9.5 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.0/9.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 5.5 MB/s eta 0:00:00
# Installing collected packages: pywin32
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 306
#     Uninstalling pywin32-306:
#       Successfully uninstalled pywin32-306
# Successfully installed pywin32-305.1

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import logging
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot
import matplotlib.pyplot as plt
import warnings
import random

warnings.filterwarnings('ignore')
logging.getLogger('cmdstanpy').setLevel(logging.WARNING)

# =====================================================================
# FUNGSI KLASIFIKASI STATUS GIZI (SIMULASI SEMENTARA)
# =====================================================================
def klasifikasi_status_gizi(z_score, indikator):
    if indikator == 'BB/U': # Berat Badan
        if z_score < -3: return "BB Sangat Kurang (Severe Underweight)"
        elif -3 <= z_score < -2: return "BB Kurang (Underweight)"
        elif -2 <= z_score <= 1: return "Berat Badan Normal"
        elif z_score > 1: return "Risiko Berat Badan Lebih"
    elif indikator == 'TB/U': # Tinggi Badan
        if z_score < -3: return "Sangat Pendek (Severe Stunted)"
        elif -3 <= z_score < -2: return "Pendek (Stunted)"
        elif -2 <= z_score <= 3: return "Normal"
        elif z_score > 3: return "Tinggi"
    elif indikator == 'LK/U': # Lingkar Kepala
        if z_score < -2: return "Mikrosefali (Kepala Terlalu Kecil)"
        elif -2 <= z_score <= 2: return "Normal"
        elif z_score > 2: return "Makrosefali (Kepala Terlalu Besar)"
    return "Tidak Diketahui"

# =====================================================================
# 1. PERSIAPAN DATA
# =====================================================================
print("Memuat dataset...")
# Ganti dengan path file yang benar
df = pd.read_excel('DATA2_GABUNGAN_7_POSYANDU.xlsx')
df.columns = df.columns.str.strip().str.lower()
df['tanggal_ukur'] = pd.to_datetime(df['tanggal_ukur'])
daftar_anak = df['nama_anak'].unique()

daftar_indikator = ['berat', 'tinggi', 'lingkar_kepala']

# LOOP BESAR UNTUK KETIGA INDIKATOR
for metrik in daftar_indikator:
    print(f"\n\n{'='*80}")
    print(f"🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: {metrik.upper()}")
    print(f"{'='*80}")
    
    hasil_evaluasi_global = []

    # =================================================================
    # 2. FASE EVALUASI GLOBAL PER INDIKATOR
    # =================================================================
    for nama in daftar_anak:
        df_anak = df[df['nama_anak'] == nama].copy()
        df_anak = df_anak.dropna(subset=['tanggal_ukur']).sort_values('tanggal_ukur')
        
        if len(df_anak) < 10 or metrik not in df_anak.columns:
            continue 
            
        df_prophet = df_anak[['tanggal_ukur', metrik]].copy().rename(columns={'tanggal_ukur': 'ds', metrik: 'y'}).dropna()
        if len(df_prophet) < 10:
            continue

        train_size = int(len(df_prophet) * 0.8)
        data_latih = df_prophet.iloc[:train_size].copy()
        data_uji = df_prophet.iloc[train_size:].copy()
        
        if data_uji.empty:
            continue
            
        ### PERBAIKAN 1: Tuning Parameter Prophet ###
        # changepoint_prior_scale dinaikkan agar garis trend lebih fleksibel mengikuti belokan data
        # changepoint_range diset 0.95 agar model tetap belajar dari data-data terakhir sebelum test data
        model = Prophet(
            yearly_seasonality=False, 
            weekly_seasonality=False, 
            daily_seasonality=False,
            changepoint_prior_scale=0.5, 
            changepoint_range=0.95
        )
        model.fit(data_latih)
        forecast = model.predict(data_uji[['ds']])
        
        y_asli = data_uji['y'].values
        y_tebakan = forecast['yhat'].values
        
        error = y_asli - y_tebakan
        mae = np.mean(np.abs(error))
        rmse = np.sqrt(np.mean(error**2))
        mape = np.mean(np.abs(error / np.where(y_asli == 0, 1, y_asli))) * 100
        
        hasil_evaluasi_global.append({
            'Nama': nama,
            'MAE': mae,
            'RMSE': rmse,
            'MAPE': mape
        })

    if not hasil_evaluasi_global:
        print(f"Tidak ada data yang cukup untuk evaluasi indikator {metrik}.")
        continue

    df_eval = pd.DataFrame(hasil_evaluasi_global)

    rata_mae = df_eval['MAE'].mean()
    rata_rmse = df_eval['RMSE'].mean()
    rata_mape = df_eval['MAPE'].mean()
    akurasi_sistem = 100 - rata_mape
    satuan = "Kg" if metrik == 'berat' else "Cm"

    print(f"\nTABEL PERFORMA GLOBAL - {metrik.upper()}")
    print("-" * 50)
    print(f"Total Balita Dievaluasi : {len(df_eval)} anak")
    print(f"Rata-rata MAE           : {rata_mae:.2f} {satuan}")
    print(f"Rata-rata RMSE          : {rata_rmse:.2f} {satuan}")
    print(f"Rata-rata MAPE          : {rata_mape:.2f} %")
    print(f"⭐ AKURASI SISTEM       : {akurasi_sistem:.2f} %")
    print("-" * 50 + "\n")

    # =================================================================
    # 4. MENENTUKAN 3 STUDI KASUS
    # =================================================================
    idx_terbaik = df_eval['MAPE'].idxmin()
    idx_terburuk = df_eval['MAPE'].idxmax()
    df_eval['Selisih_dari_Mean'] = abs(df_eval['MAPE'] - rata_mape)
    idx_menengah = df_eval['Selisih_dari_Mean'].idxmin()

    studi_kasus = {
        'TERBAIK (MAPE Terkecil)': df_eval.loc[idx_terbaik, 'Nama'],
        'MENENGAH (Mewakili Rata-rata)': df_eval.loc[idx_menengah, 'Nama'],
        'TERBURUK (MAPE Terbesar)': df_eval.loc[idx_terburuk, 'Nama']
    }

    if metrik == 'berat': kode_ind = 'BB/U'
    elif metrik == 'tinggi': kode_ind = 'TB/U'
    else: kode_ind = 'LK/U'

    # =================================================================
    # 5. MENCETAK GRAFIK KHUSUS UNTUK 3 ANAK STUDI KASUS
    # =================================================================
    for kategori, nama_target in studi_kasus.items():
        eval_anak = df_eval[df_eval['Nama'] == nama_target].iloc[0]
        
        df_anak = df[df['nama_anak'] == nama_target].copy().dropna(subset=['tanggal_ukur']).sort_values('tanggal_ukur')
        df_prophet = df_anak[['tanggal_ukur', metrik]].copy().rename(columns={'tanggal_ukur': 'ds', metrik: 'y'}).dropna()
        
        train_size = int(len(df_prophet) * 0.8)
        data_latih = df_prophet.iloc[:train_size].copy()
        data_uji = df_prophet.iloc[train_size:].copy()
        
        ### PERBAIKAN 2: Tuning Model untuk Plot Kasus ###
        model = Prophet(
            yearly_seasonality=False, 
            weekly_seasonality=False, 
            daily_seasonality=False,
            changepoint_prior_scale=0.01, 
            changepoint_range=0.95
        )
        model.fit(data_latih)
        forecast = model.predict(data_uji[['ds']])
        
        z_score_simulasi = round(random.uniform(-3.0, 1.5), 2) 
        status_gizi = klasifikasi_status_gizi(z_score_simulasi, kode_ind)
        
        print(f"\n📌 STUDI KASUS {kategori.upper()} | INDIKATOR: {metrik.upper()}")
        print(f"Nama Anak      : {nama_target.upper()}")
        print(f"MAE Anak Ini   : {eval_anak['MAE']:.3f} {satuan}")
        print(f"RMSE Anak Ini  : {eval_anak['RMSE']:.3f} {satuan}")
        print(f"MAPE Anak Ini  : {eval_anak['MAPE']:.2f}% (Akurasi: {100-eval_anak['MAPE']:.2f}%)")
        print(f"Status Gizi    : {status_gizi} (Simulasi Z-Score: {z_score_simulasi})")

        df_tabel = pd.DataFrame({
            'Bulan_Ke': range(1, len(data_uji) + 1),
            'Tanggal': data_uji['ds'].dt.strftime('%Y-%m-%d').values,
            'Aktual': data_uji['y'].values,
            'Prediksi': np.round(forecast['yhat'].values, 3)
        })
        
        df_tabel['|Error|'] = np.abs(df_tabel['Aktual'] - df_tabel['Prediksi']).round(3)
        df_tabel['Error_%'] = (np.abs(df_tabel['|Error|'] / np.where(df_tabel['Aktual'] == 0, 1, df_tabel['Aktual'])) * 100).round(2)
        
        print("\nTABEL PERBANDINGAN AKTUAL VS PREDIKSI:")
        print("-" * 75)
        print(df_tabel.to_string(index=False))
        print("-" * 75)

        # Grafik 1: Forecast bawaan Prophet
        fig1 = model.plot(forecast, figsize=(10, 4))
        a = add_changepoints_to_plot(fig1.gca(), model, forecast)
        plt.title(f"Forecast {metrik.capitalize()} - {nama_target}", fontweight='bold')
        plt.show()

        ### PERBAIKAN 3: Merenggangkan Sumbu X pada Grafik Aktual vs Prediksi ###
        # Kita ubah sumbu X dari "tanggal" menjadi urutan angka (Bulan ke-X)
        urutan_bulan = range(1, len(data_uji) + 1)
        
        plt.figure(figsize=(10, 4))
        plt.plot(urutan_bulan, data_uji['y'], label='Data Asli (Aktual)', marker='o', color='black')
        plt.plot(urutan_bulan, forecast['yhat'], label='Prediksi Model', marker='x', color='red', linestyle='--')
        plt.fill_between(urutan_bulan, forecast['yhat_lower'], forecast['yhat_upper'], color='red', alpha=0.1, label='Batas Toleransi')
        
        plt.title(f"Aktual vs Prediksi {metrik.capitalize()} - {nama_target}", fontweight='bold')
        plt.xlabel('Bulan Pengukuran Uji')
        plt.ylabel(f'{metrik.capitalize()} ({satuan})')
        
        # Atur batas X-Axis secara manual sampai angka 40 (bisa diganti 50 jika kurang panjang)
        plt.xlim(0, 40)
        
        plt.legend(loc='upper left')
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.show()

print("\n[INFO] Seluruh proses evaluasi untuk 3 indikator telah selesai!")
# Out:
# Memuat dataset...
#
#
# ================================================================================
# 🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: BERAT
# ================================================================================
#
# TABEL PERFORMA GLOBAL - BERAT
# --------------------------------------------------
# Total Balita Dievaluasi : 259 anak
# Rata-rata MAE           : 0.64 Kg
# Rata-rata RMSE          : 0.71 Kg
# Rata-rata MAPE          : 3.84 %
# ⭐ AKURASI SISTEM       : 96.16 %
# --------------------------------------------------
#
#
# 📌 STUDI KASUS TERBAIK (MAPE TERKECIL) | INDIKATOR: BERAT
# Nama Anak      : REYHAN WIJAYA
# MAE Anak Ini   : 0.051 Kg
# RMSE Anak Ini  : 0.068 Kg
# MAPE Anak Ini  : 0.24% (Akurasi: 99.76%)
# Status Gizi    : Berat Badan Normal (Simulasi Z-Score: 0.5)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-12    20.3    18.962    1.338     6.59
#         2 2024-09-05    20.8    19.144    1.656     7.96
#         3 2024-10-10    21.3    19.410    1.890     8.87
#         4 2024-11-12    21.8    19.661    2.139     9.81
#         5 2024-12-08    22.2    19.859    2.341    10.55
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS MENENGAH (MEWAKILI RATA-RATA) | INDIKATOR: BERAT
# Nama Anak      : M. FATAN ALFARIZKI
# MAE Anak Ini   : 0.606 Kg
# RMSE Anak Ini  : 0.636 Kg
# MAPE Anak Ini  : 3.88% (Akurasi: 96.12%)
# Status Gizi    : Berat Badan Normal (Simulasi Z-Score: -1.03)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-07-10    15.2    15.415    0.215     1.41
#         2 2024-08-10    15.5    15.603    0.103     0.66
#         3 2024-09-10    15.5    15.790    0.290     1.87
#         4 2024-10-10    15.8    15.972    0.172     1.09
#         5 2024-11-10    15.9    16.160    0.260     1.64
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS TERBURUK (MAPE TERBESAR) | INDIKATOR: BERAT
# Nama Anak      : NAUZAN AZMI R
# MAE Anak Ini   : 3.468 Kg
# RMSE Anak Ini  : 3.676 Kg
# MAPE Anak Ini  : 20.20% (Akurasi: 79.80%)
# Status Gizi    : Berat Badan Normal (Simulasi Z-Score: 0.45)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-06    16.2    16.413    0.213     1.31
#         2 2024-09-06    16.5    16.601    0.101     0.61
#         3 2024-10-06    17.5    16.782    0.718     4.10
#         4 2024-11-06    17.1    16.970    0.130     0.76
#         5 2024-12-06    17.8    17.151    0.649     3.65
# ---------------------------------------------------------------------------
# ================================================================================
# 🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: TINGGI
# ================================================================================
#
# TABEL PERFORMA GLOBAL - TINGGI
# --------------------------------------------------
# Total Balita Dievaluasi : 259 anak
# Rata-rata MAE           : 1.07 Cm
# Rata-rata RMSE          : 1.18 Cm
# Rata-rata MAPE          : 1.08 %
# ⭐ AKURASI SISTEM       : 98.92 %
# --------------------------------------------------
#
#
# 📌 STUDI KASUS TERBAIK (MAPE TERKECIL) | INDIKATOR: TINGGI
# Nama Anak      : M. ADAM RAMADHAN S
# MAE Anak Ini   : 0.047 Cm
# RMSE Anak Ini  : 0.052 Cm
# MAPE Anak Ini  : 0.04% (Akurasi: 99.96%)
# Status Gizi    : Normal (Simulasi Z-Score: -1.53)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-08   108.0   108.581    0.581     0.54
#         2 2024-09-08   108.5   109.274    0.774     0.71
#         3 2024-10-08   108.8   109.945    1.145     1.05
#         4 2024-11-08   109.3   110.638    1.338     1.22
#         5 2024-12-08   109.7   111.309    1.609     1.47
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS MENENGAH (MEWAKILI RATA-RATA) | INDIKATOR: TINGGI
# Nama Anak      : M.ALFARIZI SHAGUFTA
# MAE Anak Ini   : 1.137 Cm
# RMSE Anak Ini  : 1.273 Cm
# MAPE Anak Ini  : 1.08% (Akurasi: 98.92%)
# Status Gizi    : Normal (Simulasi Z-Score: -1.5)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-06   104.5   105.990    1.490     1.43
#         2 2024-09-06   104.1   106.746    2.646     2.54
#         3 2024-10-06   106.1   107.477    1.377     1.30
#         4 2024-11-06   105.2   108.233    3.033     2.88
#         5 2024-12-06   106.6   108.964    2.364     2.22
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS TERBURUK (MAPE TERBESAR) | INDIKATOR: TINGGI
# Nama Anak      : VIRENDRA ADNAN
# MAE Anak Ini   : 6.653 Cm
# RMSE Anak Ini  : 8.913 Cm
# MAPE Anak Ini  : 8.27% (Akurasi: 91.73%)
# Status Gizi    : Normal (Simulasi Z-Score: 0.55)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2023-10-06    78.9    80.362    1.462     1.85
#         2 2023-10-08    80.1    80.393    0.293     0.37
#         3 2023-12-09    80.7    81.353    0.653     0.81
# ---------------------------------------------------------------------------
# ================================================================================
# 🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: LINGKAR_KEPALA
# ================================================================================
#
# TABEL PERFORMA GLOBAL - LINGKAR_KEPALA
# --------------------------------------------------
# Total Balita Dievaluasi : 259 anak
# Rata-rata MAE           : 0.36 Cm
# Rata-rata RMSE          : 0.40 Cm
# Rata-rata MAPE          : 0.73 %
# ⭐ AKURASI SISTEM       : 99.27 %
# --------------------------------------------------
#
#
# 📌 STUDI KASUS TERBAIK (MAPE TERKECIL) | INDIKATOR: LINGKAR_KEPALA
# Nama Anak      : KIARA ARSYILA KHANZA
# MAE Anak Ini   : 0.000 Cm
# RMSE Anak Ini  : 0.000 Cm
# MAPE Anak Ini  : 0.00% (Akurasi: 100.00%)
# Status Gizi    : Normal (Simulasi Z-Score: 0.07)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-08    49.5    49.667    0.167     0.34
#         2 2024-09-08    49.5    49.740    0.240     0.48
#         3 2024-10-08    49.5    49.811    0.311     0.63
#         4 2024-11-08    49.5    49.885    0.385     0.78
#         5 2024-12-08    49.5    49.956    0.456     0.92
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS MENENGAH (MEWAKILI RATA-RATA) | INDIKATOR: LINGKAR_KEPALA
# Nama Anak      : AHMAD RAFISQI
# MAE Anak Ini   : 0.366 Cm
# RMSE Anak Ini  : 0.423 Cm
# MAPE Anak Ini  : 0.74% (Akurasi: 99.26%)
# Status Gizi    : Mikrosefali (Kepala Terlalu Kecil) (Simulasi Z-Score: -2.33)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-06-12    49.5    49.278    0.222     0.45
#         2 2024-07-05    49.6    49.290    0.310     0.62
#         3 2024-09-10    49.8    49.325    0.475     0.95
#         4 2024-11-05    49.8    49.355    0.445     0.89
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS TERBURUK (MAPE TERBESAR) | INDIKATOR: LINGKAR_KEPALA
# Nama Anak      : M. HAMDAN ALKAHFI
# MAE Anak Ini   : 2.699 Cm
# RMSE Anak Ini  : 3.001 Cm
# MAPE Anak Ini  : 5.27% (Akurasi: 94.73%)
# Status Gizi    : Normal (Simulasi Z-Score: -0.11)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-06    51.3    51.233    0.067     0.13
#         2 2024-09-06    51.8    51.304    0.496     0.96
#         3 2024-10-06    51.0    51.374    0.374     0.73
#         4 2024-11-06    51.8    51.446    0.354     0.68
#         5 2024-12-06    50.9    51.515    0.615     1.21
# ---------------------------------------------------------------------------
# [INFO] Seluruh proses evaluasi untuk 3 indikator telah selesai!

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import logging
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot
import matplotlib.pyplot as plt
import warnings
import random

warnings.filterwarnings('ignore')
logging.getLogger('cmdstanpy').setLevel(logging.WARNING)

# =====================================================================
# FUNGSI KLASIFIKASI STATUS GIZI (SIMULASI SEMENTARA)
# =====================================================================
def klasifikasi_status_gizi(z_score, indikator):
    if indikator == 'BB/U': # Berat Badan
        if z_score < -3: return "BB Sangat Kurang (Severe Underweight)"
        elif -3 <= z_score < -2: return "BB Kurang (Underweight)"
        elif -2 <= z_score <= 1: return "Berat Badan Normal"
        elif z_score > 1: return "Risiko Berat Badan Lebih"
    elif indikator == 'TB/U': # Tinggi Badan
        if z_score < -3: return "Sangat Pendek (Severe Stunted)"
        elif -3 <= z_score < -2: return "Pendek (Stunted)"
        elif -2 <= z_score <= 3: return "Normal"
        elif z_score > 3: return "Tinggi"
    elif indikator == 'LK/U': # Lingkar Kepala
        if z_score < -2: return "Mikrosefali (Kepala Terlalu Kecil)"
        elif -2 <= z_score <= 2: return "Normal"
        elif z_score > 2: return "Makrosefali (Kepala Terlalu Besar)"
    return "Tidak Diketahui"

# =====================================================================
# 1. PERSIAPAN DATA
# =====================================================================
print("Memuat dataset...")
# Ganti dengan path file yang benar
df = pd.read_excel('DATA2_GABUNGAN_7_POSYANDU.xlsx')
df.columns = df.columns.str.strip().str.lower()
df['tanggal_ukur'] = pd.to_datetime(df['tanggal_ukur'])
daftar_anak = df['nama_anak'].unique()

daftar_indikator = ['berat', 'tinggi', 'lingkar_kepala']

# LOOP BESAR UNTUK KETIGA INDIKATOR
for metrik in daftar_indikator:
    print(f"\n\n{'='*80}")
    print(f"🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: {metrik.upper()}")
    print(f"{'='*80}")
    
    hasil_evaluasi_global = []

    # =================================================================
    # 2. FASE EVALUASI GLOBAL PER INDIKATOR
    # =================================================================
    for nama in daftar_anak:
        df_anak = df[df['nama_anak'] == nama].copy()
        df_anak = df_anak.dropna(subset=['tanggal_ukur']).sort_values('tanggal_ukur')
        
        if len(df_anak) < 10 or metrik not in df_anak.columns:
            continue 
            
        df_prophet = df_anak[['tanggal_ukur', metrik]].copy().rename(columns={'tanggal_ukur': 'ds', metrik: 'y'}).dropna()
        if len(df_prophet) < 10:
            continue

        train_size = int(len(df_prophet) * 0.8)
        data_latih = df_prophet.iloc[:train_size].copy()
        data_uji = df_prophet.iloc[train_size:].copy()
        
        if data_uji.empty:
            continue
            
        # Model Fase 2 (Untuk mencari akurasi Global)
        model = Prophet(
            yearly_seasonality=False, 
            weekly_seasonality=False, 
            daily_seasonality=False,
            changepoint_prior_scale=0.5,  # <-- PARAMETER INI SAMA DENGAN FASE 5
            changepoint_range=0.95
        )
        model.fit(data_latih)
        forecast = model.predict(data_uji[['ds']])
        
        y_asli = data_uji['y'].values
        y_tebakan = forecast['yhat'].values
        
        error = y_asli - y_tebakan
        mae = np.mean(np.abs(error))
        rmse = np.sqrt(np.mean(error**2))
        mape = np.mean(np.abs(error / np.where(y_asli == 0, 1, y_asli))) * 100
        
        hasil_evaluasi_global.append({
            'Nama': nama,
            'MAE': mae,
            'RMSE': rmse,
            'MAPE': mape
        })

    if not hasil_evaluasi_global:
        print(f"Tidak ada data yang cukup untuk evaluasi indikator {metrik}.")
        continue

    df_eval = pd.DataFrame(hasil_evaluasi_global)

    rata_mae = df_eval['MAE'].mean()
    rata_rmse = df_eval['RMSE'].mean()
    rata_mape = df_eval['MAPE'].mean()
    akurasi_sistem = 100 - rata_mape
    satuan = "Kg" if metrik == 'berat' else "Cm"

    print(f"\nTABEL PERFORMA GLOBAL - {metrik.upper()}")
    print("-" * 50)
    print(f"Total Balita Dievaluasi : {len(df_eval)} anak")
    print(f"Rata-rata MAE           : {rata_mae:.2f} {satuan}")
    print(f"Rata-rata RMSE          : {rata_rmse:.2f} {satuan}")
    print(f"Rata-rata MAPE          : {rata_mape:.2f} %")
    print(f"⭐ AKURASI SISTEM       : {akurasi_sistem:.2f} %")
    print("-" * 50 + "\n")

    # =================================================================
    # 4. MENENTUKAN 3 STUDI KASUS
    # =================================================================
    idx_terbaik = df_eval['MAPE'].idxmin()
    idx_terburuk = df_eval['MAPE'].idxmax()
    df_eval['Selisih_dari_Mean'] = abs(df_eval['MAPE'] - rata_mape)
    idx_menengah = df_eval['Selisih_dari_Mean'].idxmin()

    studi_kasus = {
        'TERBAIK (MAPE Terkecil)': df_eval.loc[idx_terbaik, 'Nama'],
        'MENENGAH (Mewakili Rata-rata)': df_eval.loc[idx_menengah, 'Nama'],
        'TERBURUK (MAPE Terbesar)': df_eval.loc[idx_terburuk, 'Nama']
    }

    if metrik == 'berat': kode_ind = 'BB/U'
    elif metrik == 'tinggi': kode_ind = 'TB/U'
    else: kode_ind = 'LK/U'

    # =================================================================
    # 5. MENCETAK GRAFIK KHUSUS UNTUK 3 ANAK STUDI KASUS
    # =================================================================
    for kategori, nama_target in studi_kasus.items():
        eval_anak = df_eval[df_eval['Nama'] == nama_target].iloc[0]
        
        df_anak = df[df['nama_anak'] == nama_target].copy().dropna(subset=['tanggal_ukur']).sort_values('tanggal_ukur')
        df_prophet = df_anak[['tanggal_ukur', metrik]].copy().rename(columns={'tanggal_ukur': 'ds', metrik: 'y'}).dropna()
        
        train_size = int(len(df_prophet) * 0.8)
        data_latih = df_prophet.iloc[:train_size].copy()
        data_uji = df_prophet.iloc[train_size:].copy()
        
        # Model Fase 5 (Untuk plot grafik)
        model = Prophet(
            yearly_seasonality=False, 
            weekly_seasonality=False, 
            daily_seasonality=False,
            changepoint_prior_scale=0.5, # <-- DISAMAKAN DENGAN FASE 2
            changepoint_range=0.95
        )
        model.fit(data_latih)
        forecast = model.predict(data_uji[['ds']])
        
        z_score_simulasi = round(random.uniform(-3.0, 1.5), 2) 
        status_gizi = klasifikasi_status_gizi(z_score_simulasi, kode_ind)
        
        print(f"\n📌 STUDI KASUS {kategori.upper()} | INDIKATOR: {metrik.upper()}")
        print(f"Nama Anak      : {nama_target.upper()}")
        print(f"MAE Anak Ini   : {eval_anak['MAE']:.3f} {satuan}")
        print(f"RMSE Anak Ini  : {eval_anak['RMSE']:.3f} {satuan}")
        print(f"MAPE Anak Ini  : {eval_anak['MAPE']:.2f}% (Akurasi: {100-eval_anak['MAPE']:.2f}%)")
        print(f"Status Gizi    : {status_gizi} (Simulasi Z-Score: {z_score_simulasi})")

        df_tabel = pd.DataFrame({
            'Bulan_Ke': range(1, len(data_uji) + 1),
            'Tanggal': data_uji['ds'].dt.strftime('%Y-%m-%d').values,
            'Aktual': data_uji['y'].values,
            'Prediksi': np.round(forecast['yhat'].values, 3)
        })
        
        df_tabel['|Error|'] = np.abs(df_tabel['Aktual'] - df_tabel['Prediksi']).round(3)
        df_tabel['Error_%'] = (np.abs(df_tabel['|Error|'] / np.where(df_tabel['Aktual'] == 0, 1, df_tabel['Aktual'])) * 100).round(2)
        
        print("\nTABEL PERBANDINGAN AKTUAL VS PREDIKSI:")
        print("-" * 75)
        print(df_tabel.to_string(index=False))
        print("-" * 75)

        # Grafik 1: Forecast bawaan Prophet
        fig1 = model.plot(forecast, figsize=(10, 4))
        a = add_changepoints_to_plot(fig1.gca(), model, forecast)
        plt.title(f"Forecast {metrik.capitalize()} - {nama_target}", fontweight='bold')
        plt.show()

        # Grafik 2: Aktual vs Prediksi
        urutan_bulan = range(1, len(data_uji) + 1)
        
        plt.figure(figsize=(10, 4))
        plt.plot(urutan_bulan, data_uji['y'], label='Data Asli (Aktual)', marker='o', color='black')
        plt.plot(urutan_bulan, forecast['yhat'], label='Prediksi Model', marker='x', color='red', linestyle='--')
        plt.fill_between(urutan_bulan, forecast['yhat_lower'], forecast['yhat_upper'], color='red', alpha=0.1, label='Batas Toleransi')
        
        plt.title(f"Aktual vs Prediksi {metrik.capitalize()} - {nama_target}", fontweight='bold')
        plt.xlabel('Bulan Pengukuran Uji')
        plt.ylabel(f'{metrik.capitalize()} ({satuan})')
        
        # ATUR SUMBU X (Agar data proporsional menempati ruang)
        plt.xlim(0, len(data_uji) + 1) 
        
        # ATUR SUMBU Y (Disesuaikan berdasarkan metrik yang diproses)
        if metrik == 'berat':
            plt.ylim(bottom=max(0, min(data_uji['y']) - 2), top=40)
        elif metrik == 'tinggi':
            plt.ylim(bottom=max(0, min(data_uji['y']) - 5), top=120)
        elif metrik == 'lingkar_kepala':
            plt.ylim(bottom=max(0, min(data_uji['y']) - 2), top=60)
        
        plt.legend(loc='upper left')
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.show()

print("\n[INFO] Seluruh proses evaluasi untuk 3 indikator telah selesai!")
# Out:
# Memuat dataset...
#
#
# ================================================================================
# 🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: BERAT
# ================================================================================
#
# TABEL PERFORMA GLOBAL - BERAT
# --------------------------------------------------
# Total Balita Dievaluasi : 259 anak
# Rata-rata MAE           : 0.64 Kg
# Rata-rata RMSE          : 0.71 Kg
# Rata-rata MAPE          : 3.84 %
# ⭐ AKURASI SISTEM       : 96.16 %
# --------------------------------------------------
#
#
# 📌 STUDI KASUS TERBAIK (MAPE TERKECIL) | INDIKATOR: BERAT
# Nama Anak      : REYHAN WIJAYA
# MAE Anak Ini   : 0.051 Kg
# RMSE Anak Ini  : 0.068 Kg
# MAPE Anak Ini  : 0.24% (Akurasi: 99.76%)
# Status Gizi    : Berat Badan Normal (Simulasi Z-Score: 0.06)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-12    20.3    20.270    0.030     0.15
#         2 2024-09-05    20.8    20.665    0.135     0.65
#         3 2024-10-10    21.3    21.241    0.059     0.28
#         4 2024-11-12    21.8    21.784    0.016     0.07
#         5 2024-12-08    22.2    22.212    0.012     0.05
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS MENENGAH (MEWAKILI RATA-RATA) | INDIKATOR: BERAT
# Nama Anak      : M. FATAN ALFARIZKI
# MAE Anak Ini   : 0.606 Kg
# RMSE Anak Ini  : 0.636 Kg
# MAPE Anak Ini  : 3.88% (Akurasi: 96.12%)
# Status Gizi    : BB Kurang (Underweight) (Simulasi Z-Score: -2.48)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-07-10    15.2    15.590    0.390     2.57
#         2 2024-08-10    15.5    15.890    0.390     2.52
#         3 2024-09-10    15.5    16.190    0.690     4.45
#         4 2024-10-10    15.8    16.481    0.681     4.31
#         5 2024-11-10    15.9    16.781    0.881     5.54
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS TERBURUK (MAPE TERBESAR) | INDIKATOR: BERAT
# Nama Anak      : NAUZAN AZMI R
# MAE Anak Ini   : 3.468 Kg
# RMSE Anak Ini  : 3.676 Kg
# MAPE Anak Ini  : 20.20% (Akurasi: 79.80%)
# Status Gizi    : Berat Badan Normal (Simulasi Z-Score: -0.76)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-06    16.2     18.04     1.84    11.36
#         2 2024-09-06    16.5     19.28     2.78    16.85
#         3 2024-10-06    17.5     20.48     2.98    17.03
#         4 2024-11-06    17.1     21.72     4.62    27.02
#         5 2024-12-06    17.8     22.92     5.12    28.76
# ---------------------------------------------------------------------------
# ================================================================================
# 🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: TINGGI
# ================================================================================
#
# TABEL PERFORMA GLOBAL - TINGGI
# --------------------------------------------------
# Total Balita Dievaluasi : 259 anak
# Rata-rata MAE           : 1.07 Cm
# Rata-rata RMSE          : 1.18 Cm
# Rata-rata MAPE          : 1.08 %
# ⭐ AKURASI SISTEM       : 98.92 %
# --------------------------------------------------
#
#
# 📌 STUDI KASUS TERBAIK (MAPE TERKECIL) | INDIKATOR: TINGGI
# Nama Anak      : M. ADAM RAMADHAN S
# MAE Anak Ini   : 0.047 Cm
# RMSE Anak Ini  : 0.052 Cm
# MAPE Anak Ini  : 0.04% (Akurasi: 99.96%)
# Status Gizi    : Normal (Simulasi Z-Score: 0.92)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-08   108.0   108.013    0.013     0.01
#         2 2024-09-08   108.5   108.427    0.073     0.07
#         3 2024-10-08   108.8   108.827    0.027     0.02
#         4 2024-11-08   109.3   109.240    0.060     0.05
#         5 2024-12-08   109.7   109.640    0.060     0.05
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS MENENGAH (MEWAKILI RATA-RATA) | INDIKATOR: TINGGI
# Nama Anak      : M.ALFARIZI SHAGUFTA
# MAE Anak Ini   : 1.137 Cm
# RMSE Anak Ini  : 1.273 Cm
# MAPE Anak Ini  : 1.08% (Akurasi: 98.92%)
# Status Gizi    : Normal (Simulasi Z-Score: 0.26)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-06   104.5   105.417    0.917     0.88
#         2 2024-09-06   104.1   105.933    1.833     1.76
#         3 2024-10-06   106.1   106.433    0.333     0.31
#         4 2024-11-06   105.2   106.950    1.750     1.66
#         5 2024-12-06   106.6   107.450    0.850     0.80
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS TERBURUK (MAPE TERBESAR) | INDIKATOR: TINGGI
# Nama Anak      : VIRENDRA ADNAN
# MAE Anak Ini   : 6.653 Cm
# RMSE Anak Ini  : 8.913 Cm
# MAPE Anak Ini  : 8.27% (Akurasi: 91.73%)
# Status Gizi    : Normal (Simulasi Z-Score: 0.15)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2023-10-06    78.9    77.197    1.703     2.16
#         2 2023-10-08    80.1    76.838    3.262     4.07
#         3 2023-12-09    80.7    65.707   14.993    18.58
# ---------------------------------------------------------------------------
# ================================================================================
# 🚀 MEMULAI ANALISIS SISTEM UNTUK INDIKATOR: LINGKAR_KEPALA
# ================================================================================
#
# TABEL PERFORMA GLOBAL - LINGKAR_KEPALA
# --------------------------------------------------
# Total Balita Dievaluasi : 259 anak
# Rata-rata MAE           : 0.36 Cm
# Rata-rata RMSE          : 0.40 Cm
# Rata-rata MAPE          : 0.73 %
# ⭐ AKURASI SISTEM       : 99.27 %
# --------------------------------------------------
#
#
# 📌 STUDI KASUS TERBAIK (MAPE TERKECIL) | INDIKATOR: LINGKAR_KEPALA
# Nama Anak      : KIARA ARSYILA KHANZA
# MAE Anak Ini   : 0.000 Cm
# RMSE Anak Ini  : 0.000 Cm
# MAPE Anak Ini  : 0.00% (Akurasi: 100.00%)
# Status Gizi    : Normal (Simulasi Z-Score: -1.31)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-08    49.5      49.5      0.0      0.0
#         2 2024-09-08    49.5      49.5      0.0      0.0
#         3 2024-10-08    49.5      49.5      0.0      0.0
#         4 2024-11-08    49.5      49.5      0.0      0.0
#         5 2024-12-08    49.5      49.5      0.0      0.0
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS MENENGAH (MEWAKILI RATA-RATA) | INDIKATOR: LINGKAR_KEPALA
# Nama Anak      : AHMAD RAFISQI
# MAE Anak Ini   : 0.366 Cm
# RMSE Anak Ini  : 0.423 Cm
# MAPE Anak Ini  : 0.74% (Akurasi: 99.26%)
# Status Gizi    : Normal (Simulasi Z-Score: 1.08)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-06-12    49.5    49.671    0.171     0.35
#         2 2024-07-05    49.6    49.803    0.203     0.41
#         3 2024-09-10    49.8    50.186    0.386     0.78
#         4 2024-11-05    49.8    50.506    0.706     1.42
# ---------------------------------------------------------------------------
# 📌 STUDI KASUS TERBURUK (MAPE TERBESAR) | INDIKATOR: LINGKAR_KEPALA
# Nama Anak      : M. HAMDAN ALKAHFI
# MAE Anak Ini   : 2.699 Cm
# RMSE Anak Ini  : 3.001 Cm
# MAPE Anak Ini  : 5.27% (Akurasi: 94.73%)
# Status Gizi    : Normal (Simulasi Z-Score: -1.85)
#
# TABEL PERBANDINGAN AKTUAL VS PREDIKSI:
# ---------------------------------------------------------------------------
#  Bulan_Ke    Tanggal  Aktual  Prediksi  |Error|  Error_%
#         1 2024-08-06    51.3    52.427    1.127     2.20
#         2 2024-09-06    51.8    53.253    1.453     2.81
#         3 2024-10-06    51.0    54.053    3.053     5.99
#         4 2024-11-06    51.8    54.880    3.080     5.95
#         5 2024-12-06    50.9    55.680    4.780     9.39
# ---------------------------------------------------------------------------
# [INFO] Seluruh proses evaluasi untuk 3 indikator telah selesai!
